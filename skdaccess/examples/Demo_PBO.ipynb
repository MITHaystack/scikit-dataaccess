# %%
# Plate Boundary Observatory GPS Data
# Source: http://www.unavco.org/instrumentation/networks/status/pbo
# Time series data for GPS sensors (North, East, Up), displacement in meters versus time

# %%
from skdaccess.geo.pbo import DataFetcher as PBO_DF
from skdaccess.framework.param_class import *

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
# Latitude and Longitude range around Akutan Volcano
lat_range = AutoList((54,54.25))
lon_range = AutoList((-166, -165.6))
start_time = '2006-01-01'
end_time = '2015-06-01'

PBO_data_fetcher = PBO_DF(start_time, end_time, [lat_range, lon_range],mdyratio=.7)

# %%
PBO_data = PBO_data_fetcher.output().get() # returns an ordered dictionary of data frames
# Out:
# 100%|██████████| 6/6 [00:00<00:00, 21.18it/s]

# %%
PBO_data['AV06'].head()
# Out:
#             HHMMSS  JJJJJ.JJJJ             X             Y             Z  \
# 2006-01-01  120000     53736.5 -3.629267e+06 -920656.48751  5.146731e+06
# 2006-01-02  120000     53737.5 -3.629267e+06 -920656.48670  5.146731e+06
# 2006-01-03  120000     53738.5 -3.629267e+06 -920656.48672  5.146731e+06
# 2006-01-04  120000     53739.5 -3.629267e+06 -920656.48650  5.146731e+06
# 2006-01-05  120000     53740.5 -3.629267e+06 -920656.48658  5.146731e+06
#
#                  Sx       Sy       Sz    Rxy    Rxz  ...         dN       dE  \
# 2006-01-01  0.00339  0.00167  0.00460  0.508 -0.801  ...    0.00945  0.00935
# 2006-01-02  0.00323  0.00160  0.00441  0.506 -0.801  ...    0.01064  0.00896
# 2006-01-03  0.00332  0.00166  0.00450  0.495 -0.806  ...    0.01108  0.00937
# 2006-01-04  0.00338  0.00169  0.00457  0.492 -0.802  ...    0.00803  0.00947
# 2006-01-05  0.00331  0.00165  0.00446  0.490 -0.802  ...    0.01132  0.00890
#
#                  dU       Sn       Se       Su    Rne    Rnu    Reu   Soln
# 2006-01-01 -0.01095  0.00172  0.00139  0.00553  0.019  0.022  0.109  repro
# 2006-01-02 -0.01233  0.00165  0.00134  0.00529  0.009  0.031  0.106  repro
# 2006-01-03 -0.01432  0.00166  0.00140  0.00541  0.014  0.012  0.103  repro
# 2006-01-04 -0.02076  0.00170  0.00143  0.00550  0.029  0.016  0.106  repro
# 2006-01-05 -0.01179  0.00167  0.00139  0.00537  0.015  0.005  0.095  repro
#
# [5 rows x 24 columns]

# %%
plt.figure();
plt.plot(PBO_data['AV06']['dN']);
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
